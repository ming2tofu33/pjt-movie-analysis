# %% [markdown]
# ## 데이터 정제

# %% [markdown]
# 1 차 정제. 형변환, buget / revenue 0 인 행들 삭제. genre explode

# %%
import pandas as pd

# 1) CSV 로드
df = pd.read_csv("./data_processed/tmdb_kr_theatrical_2005_2025.csv")

# 2) 데이터 기본 정보 확인
print("원본 shape:", df.shape)
display(df.head())
df.info()

# 3) budget/revenue == 0 → 행 제거
df = df[(df["budget"] != 0) & (df["revenue"] != 0)]

# 4) ROI 계산
df["roi"] = (df["revenue"] - df["budget"]) / df["budget"]

# 5) release_date 날짜형 변환
df["release_date"] = pd.to_datetime(df["release_date"], errors="coerce")

# 6) release_year / release_month → int 변환
df["release_year"]  = df["release_year"].astype("Int64")
df["release_month"] = df["release_month"].astype("Int64")

# 7) 필수 컬럼만 dropna
df = df.dropna(subset=["budget", "revenue", "release_date", "genres"])

# 8) 장르 explode
df_exploded = df.explode("genres").reset_index(drop=True)

# 9) 장르 없는 행 제거
df_exploded = df_exploded.dropna(subset=["genres"])

# 10) 저장
df.to_csv("./data_processed/tmdb_kr_theatrical_clean.csv", index=False, encoding="utf-8")
df_exploded.to_csv("./data_processed/tmdb_kr_theatrical_clean_exploded.csv", index=False, encoding="utf-8")

# 11) 미리보기
print("전처리 후 shape:", df_exploded.shape)
display(df_exploded.head(10))
df_exploded.info()
# Out:
# 원본 shape: (4670, 16)
#    movie_id    title original_title original_language release_date  runtime  \
# 0       670     올드보이           올드보이                ko   2003-11-21      120
# 1      1255       괴물             괴물                ko   2006-07-27      119
# 2      1963        활              활                ko   2005-05-12       88
# 3      2015       밀양             밀양                ko   2007-05-23      142
# 4      4550  친절한 금자씨        친절한 금자씨                ko   2005-07-29      112
#
#      budget   revenue  vote_average  vote_count  popularity  \
# 0   3000000  17500000         8.252        9150     11.6819
# 1  11000000  88489643         6.980        2931      4.4383
# 2    950000   2032404         6.921         208      1.2098
# 3   2900000  11581469         7.193         215      1.6151
# 4         0  23803308         7.500        1752      3.3480
#
#                          genres  \
# 0  ['드라마', '스릴러', '미스터리', '액션']
# 1           ['공포', '드라마', 'SF']
# 2                       ['드라마']
# 3                       ['드라마']
# 4                ['드라마', '스릴러']
#
#                                 production_companies production_countries  \
# 0        ['Show East', 'Egg Film', 'Cineclick Asia']               ['KR']
# 1                    ['Chungeorahm Film', 'Showbox']               ['KR']
# 2  ['Kim Ki Duk Film', 'Happinet Pictures', 'Cine...         ['JP', 'KR']
# 3  ['Cinema Service', 'Pinehouse Film', 'CJ Enter...               ['KR']
# 4  ['TSJ Entertainment', 'Ilshin Capital Investme...               ['KR']
#
#    release_year  release_month
# 0        2003.0           11.0
# 1        2006.0            7.0
# 2        2005.0            5.0
# 3        2007.0            5.0
# 4        2005.0            7.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4670 entries, 0 to 4669
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movie_id              4670 non-null   int64
#  1   title                 4670 non-null   object
#  2   original_title        4670 non-null   object
#  3   original_language     4670 non-null   object
#  4   release_date          4668 non-null   object
#  5   runtime               4670 non-null   int64
#  6   budget                4670 non-null   int64
#  7   revenue               4670 non-null   int64
#  8   vote_average          4670 non-null   float64
#  9   vote_count            4670 non-null   int64
#  10  popularity            4670 non-null   float64
#  11  genres                4670 non-null   object
#  12  production_companies  4670 non-null   object
#  13  production_countries  4670 non-null   object
#  14  release_year          4668 non-null   float64
#  15  release_month         4668 non-null   float64
# dtypes: float64(4), int64(5), object(7)
# memory usage: 583.9+ KB
# 전처리 후 shape: (94, 17)
#    movie_id     title original_title original_language release_date  runtime  \
# 0       670      올드보이           올드보이                ko   2003-11-21      120
# 1      1255        괴물             괴물                ko   2006-07-27      119
# 2      1963         활              활                ko   2005-05-12       88
# 3      2015        밀양             밀양                ko   2007-05-23      142
# 4     10253       디 워            디 워                ko   2007-08-01       92
# 5     14968  웰컴 투 동막골       웰컴 투 동막골                ko   2005-08-04      133
# 6     17903       쌍화점            쌍화점                ko   2008-12-30      132
# 7     18514    두번째 사랑         두번째 사랑                ko   2007-06-20       90
# 8     19627     무림여대생          무림여대생                ko   2008-06-26      118
# 9     22536        박쥐             박쥐                ko   2009-04-30      133
#
#      budget   revenue  vote_average  vote_count  popularity  \
# 0   3000000  17500000         8.252        9150     11.6819
# 1  11000000  88489643         6.980        2931      4.4383
# 2    950000   2032404         6.921         208      1.2098
# 3   2900000  11581469         7.193         215      1.6151
# 4  32000000  75108998         4.525         428      2.3500
# 5   8000000  33579813         7.445         190      1.2664
# 6  10000000  18980744         6.899         148      4.6242
# 7   3500000    689473         6.600          44      1.6460
# 8   7000000    162256         6.519          27      1.6496
# 9   5000000  13085023         7.097         979      3.2794
#
#                                     genres  \
# 0             ['드라마', '스릴러', '미스터리', '액션']
# 1                      ['공포', '드라마', 'SF']
# 2                                  ['드라마']
# 3                                  ['드라마']
# 4  ['판타지', '드라마', '공포', '액션', '스릴러', 'SF']
# 5                     ['코미디', '드라마', '전쟁']
# 6                                  ['드라마']
# 7                           ['드라마', '로맨스']
# 8                           ['코미디', '로맨스']
# 9                     ['드라마', '공포', '스릴러']
#
#                                 production_companies production_countries  \
# 0        ['Show East', 'Egg Film', 'Cineclick Asia']               ['KR']
# 1                    ['Chungeorahm Film', 'Showbox']               ['KR']
# 2  ['Kim Ki Duk Film', 'Happinet Pictures', 'Cine...         ['JP', 'KR']
# 3  ['Cinema Service', 'Pinehouse Film', 'CJ Enter...               ['KR']
# 4                  ['Younggu-Art Movies', 'Showbox']               ['KR']
# 5                        ['Film It Suda', 'Showbox']               ['KR']
# 6  ['Opus Pictures', 'Showbox', 'United Pictures'...               ['KR']
# 7                          ['NOWFILM', 'Vox3 Films']         ['KR', 'US']
# 8      ['Bear Entertainment', 'Prime Entertainment']               ['KR']
# 9                                      ['Moho Film']               ['KR']
#
#    release_year  release_month       roi
# 0          2003             11  4.833333
# 1          2006              7  7.044513
# 2          2005              5  1.139373
# 3          2007              5  2.993610
# 4          2007              8  1.347156
# 5          2005              8  3.197477
# 6          2008             12  0.898074
# 7          2007              6 -0.803008
# 8          2008              6 -0.976821
# 9          2009              4  1.617005
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   movie_id              94 non-null     int64
#  1   title                 94 non-null     object
#  2   original_title        94 non-null     object
#  3   original_language     94 non-null     object
#  4   release_date          94 non-null     datetime64[ns]
#  5   runtime               94 non-null     int64
#  6   budget                94 non-null     int64
#  7   revenue               94 non-null     int64
#  8   vote_average          94 non-null     float64
#  9   vote_count            94 non-null     int64
#  10  popularity            94 non-null     float64
#  11  genres                94 non-null     object
#  12  production_companies  94 non-null     object
#  13  production_countries  94 non-null     object
#  14  release_year          94 non-null     Int64
#  15  release_month         94 non-null     Int64
#  16  roi                   94 non-null     float64
# dtypes: Int64(2), datetime64[ns](1), float64(3), int64(5), object(6)
# memory usage: 12.8+ KB
